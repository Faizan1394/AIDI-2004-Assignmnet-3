# %%
# !pip install flask_restful
# Out:
# Requirement already satisfied: flask_restful in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (0.3.8)
# Requirement already satisfied: Flask>=0.8 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from flask_restful) (1.1.2)
# Requirement already satisfied: pytz in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from flask_restful) (2021.1)
# Requirement already satisfied: aniso8601>=0.82 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from flask_restful) (9.0.0)
# Requirement already satisfied: six>=1.3.0 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from flask_restful) (1.15.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from Flask>=0.8->flask_restful) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from Flask>=0.8->flask_restful) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from Flask>=0.8->flask_restful) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from Flask>=0.8->flask_restful) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\faizan\anaconda3\envs\ai-cv\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.8->flask_restful) (1.1.1)

# %%
#importing required libraries
from flask import Flask, request, Response, jsonify
from flask_restful import Resource, Api, reqparse
import sqlite3

# %%
app = Flask(__name__)
api = Api(app)

#arguments required for put request to add data
addDataArgs = reqparse.RequestParser()
addDataArgs.add_argument("studentID",type=int,help="Student Number",required=True)
addDataArgs.add_argument("firstName",type=str,help="Student first name",required=True)
addDataArgs.add_argument("lastName",type=str,help="Student last name",required=True)
addDataArgs.add_argument("dob",type=str,help="Student Date of Birth",required=True)
addDataArgs.add_argument("amountDue",type=str,help="Amount Student owes",required=True)

#arguments required for delete request to delete data
delDataArgs = reqparse.RequestParser()
delDataArgs.add_argument("studentID",type=int,help="Student Number",required=True)

#arguments required for put request to update data
putDataArgs = reqparse.RequestParser()
putDataArgs.add_argument("firstName",type=str,help="Student first name",required=False)
putDataArgs.add_argument("lastName",type=str,help="Student last name",required=False)
putDataArgs.add_argument("dob",type=str,help="Student Date of Birth",required=False)
putDataArgs.add_argument("amountDue",type=str,help="Amount Student owes",required=False)


#for showing all records
class dbmAll(Resource):
    def get(self):
        pass

#for add/update/delete/and view database records
class dbm(Resource):
    def get(self):
        return  {"name":"hello world"}

    def post(self):
        args = addDataArgs.parse_args()
        #create connection to database. Will be created if it doesnt exist
        conn = sqlite3.connect('studentInfo.db')

        #create cursor instance
        c = conn.cursor()

        c.execute("""INSERT INTO Student (studentID, firstName, lastName, dateOfBirth, amountDue)
                    VALUES(?,?,?,?,?)""",
                    (args["studentID"],args["firstName"],args["lastName"],args["dob"],args["amountDue"]))

        #save the changes
        conn.commit()
        #close the connection
        conn.close()

        return  {"Added":args}

    def put(self):
        args = putDataArgs.parse_args()

        conn = sqlite3.connect('studentInfo.db')
        c = conn.cursor()

        c.execute("""UPDATE Student
                    SET firstName='', lastName='', dateOfBirth='', amountDue=0
                    VALUES(?,?,?,?)""",
                   (args["firstName"],args["lastName"],args["dob"],args["amountDue"]))

        conn.commit()
        conn.close()

        return  {"UPDATED":args}


    def delete(self):

        args = delDataArgs.parse_args()

        conn = sqlite3.connect('studentInfo.db')
        c = conn.cursor()

        c.execute("""DELETE FROM Student (studentID)
                    VALUES(?)""", (args["studentID"]))

        conn.commit()
        conn.close()

        return  {"Deleted":args}



api.add_resource(dbm,'/')
api.add_resource(dbmAll,'/all')



if __name__ == '__main__':
    app.run(port=8080, debug=True)
# Out:
#   File "<ipython-input-5-8bf011de7689>", line 80
#     conn.commit()
#     ^
# SyntaxError: invalid syntax
